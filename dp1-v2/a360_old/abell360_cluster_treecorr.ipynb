# %% [markdown]
# ## 1. Imports + cosmology

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import treecorr
from astropy.table import Table, vstack

# Manual flat-LCDM angular diameter distance for the cluster-radius
# conversion (no external cosmology dependency).
z_cl = 0.22
H0, c_light = 70.0, 3e5
omega_m, omega_de = 0.31, 0.69
Hz = lambda z: c_light / (H0 * np.sqrt(omega_de + omega_m * (1 + z) ** 3))
chi_dl = lambda z, z0=0: integrate.quad(Hz, z0, z)[0]
Da = lambda z: chi_dl(z) / (1 + z)
Da_lens = Da(z_cl)
print(f'Da(z_cl={z_cl}) = {Da_lens:.1f} Mpc')
# Out:
# Da(z_cl=0.22) = 732.0 Mpc

# %% [markdown]
# ## 2. Load the merged tract catalog

# %%
# Load per-tract merged catalogs directly from the butler (replaces the old
# laptop-local parquet paths under /home/xiangchong/work/DP1).
from lsst.daf.butler import Butler

BUTLER_CONFIG = "/global/cfs/cdirs/lsst/production/gen3/rubin/DP1/repo/butler.yaml"
ANACAL_COLLECTION = "u/xiangchl/dp1/a360_anacal"  # chained: includes 20260511T214156Z
TRACT_IDS = [10463, 10464, 10704]

butler = Butler(BUTLER_CONFIG, collections=[ANACAL_COLLECTION])

cluster_coords = (37.865017, 6.982205)
ra_bcg, dec_bcg = cluster_coords

tables = []
for tid in TRACT_IDS:
    t = butler.get(
        "deep_coadd_cell_anacal_merged",
        skymap="lsst_cells_v1",
        tract=tid,
    )
    tables.append(t)
    print(f'  tract={tid}: {len(t)} objects')

anacal_table = vstack(tables)
print(f'\nTotal merged objects: {len(anacal_table)}')
# Out:
#   tract=10463: 44768 objects
#   tract=10464: 24714 objects
#   tract=10704: 3840 objects
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.ID='019e18fd-8a63-7eca-87df-9b889ce554f8' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.DATAID.TRACT' types <class 'int'> and <class 'int'>, choosing LSST.BUTLER.DATAID.TRACT=10464 [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.QUANTUM' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.QUANTUM='019e18fd-8afd-7fad-b20e-22afd882664c' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.N_INPUTS' types <class 'int'> and <class 'int'>, choosing LSST.BUTLER.N_INPUTS=43 [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.ID='64c16b0a-0a1a-4f78-81e5-f49a9328c388' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.RUN' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.RUN='skymaps' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.DATASETTYPE='skyMap' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.1.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.1.ID='019e18fd-8a5a-7500-9360-655cb727d119' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.2.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.2.ID='019e18fd-8a5b-76ed-b74f-e29b7d667cdc' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.3.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.3.ID='019e18fd-8a5d-729e-8e08-71fcf528ba3a' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.4.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.4.ID='019e18fd-8a5e-77b8-8e4e-92e6f9f904d9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.5.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.5.ID='019e18fd-8a5b-7d8b-9678-260933ef2a2e' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.6.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.6.ID='019e18fd-8a5c-7047-9f88-6391d3b87e32' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.7.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.7.ID='019e18fd-8a5a-7c21-8b0a-6dbbeb837f57' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.8.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.8.ID='019e18fd-8a5a-711f-af05-84af3a7b935e' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.9.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.9.ID='019e18fd-8a5b-751e-a2d8-2f74d205500e' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.10.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.10.ID='019e18fd-8a5e-7ed0-a46e-142ab8eb0f41' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.11.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.11.ID='019e18fd-8a5a-77c3-9de6-661b7ba575f6' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.12.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.12.ID='019e18fd-8a5c-7a0e-aa14-0bb9b8c44b47' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.13.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.13.ID='019e18fd-8a5a-7a38-a068-7a21772b4be8' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.14.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.14.ID='019e18fd-8a5b-7fa4-bce9-8f827d32d321' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.15.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.15.ID='019e18fd-8a5b-7cd7-8f0f-41ac274cf24c' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.16.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.16.ID='019e18fd-8a5e-7394-9c0a-5f85f0f54862' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.17.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.17.ID='019e18fd-8a5a-76cd-9687-8820e2b1c784' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.18.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.18.ID='019e18fd-8a5d-7240-835c-153e28d057fb' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.19.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.19.ID='019e18fd-8a5d-736b-b6f0-7f6e1ce3ee4f' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.20.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.20.ID='019e18fd-8a5b-7aa6-89ff-93019e2006b4' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.21.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.21.ID='019e18fd-8a5b-7594-813e-1eb97db4e9eb' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.22.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.22.ID='019e18fd-8a5f-7416-a807-3ff8728f4e59' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.22.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.22.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.23.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.23.ID='019e18fd-8a60-7acc-a174-ff6008b13f92' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.23.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.23.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.24.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.24.ID='019e18fd-8a62-7615-8555-685951ebea87' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.24.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.24.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.25.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.25.ID='019e18fd-8a5f-7dc4-8239-24b818857ad6' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.25.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.25.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.26.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.26.ID='019e18fd-8a61-7786-b2d0-7252c0d67d32' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.26.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.26.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.27.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.27.ID='019e18fd-8a61-7044-84ab-bab4696ca431' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.27.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.27.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.28.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.28.ID='019e18fd-8a5f-7fc5-ae70-28b2e8dd38ab' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.28.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.28.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.29.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.29.ID='019e18fd-8a60-7bc5-9ce4-74dd6c88a642' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.29.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.29.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.30.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.30.ID='019e18fd-8a61-73ec-add6-43f4b6851848' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.30.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.30.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.31.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.31.ID='019e18fd-8a5e-7821-9182-7d0bc83d2bdd' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.31.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.31.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.32.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.32.ID='019e18fd-8a5f-7530-b005-79e8faac10f2' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.32.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.32.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.33.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.33.ID='019e18fd-8a62-7d7e-8c89-5b2c77bc0fbb' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.33.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.33.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.34.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.34.ID='019e18fd-8a60-7655-8ce7-3767ee7fbdb7' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.34.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.34.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.35.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.35.ID='019e18fd-8a60-7b81-a487-43d721ad298b' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.35.RUN' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.35.RUN='u/xiangchl/dp1/a360_anacal/20260511T214156Z' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.35.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.35.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.36.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.36.ID='019e18fd-8a61-70fe-807b-11cac8a955ce' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.37.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.37.ID='019e18fd-8a5f-72c9-8189-a41ee4c0955f' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.38.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.38.ID='019e18fd-8a5f-7061-a935-56061b008377' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.39.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.39.ID='019e18fd-8a62-7a3e-a952-da5e67c501bb' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.40.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.40.ID='019e18fd-8a63-715e-911b-5edde62a5f4b' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.41.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.41.ID='019e18fd-8a60-79da-8a4c-cddd4ab94db9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.42.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.42.ID='019e18fd-8a61-75cc-afc8-17b4a98aa2e0' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.ID='019e18fd-8a63-7f90-ac2f-ff333d0209ae' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.DATAID.TRACT' types <class 'int'> and <class 'int'>, choosing LSST.BUTLER.DATAID.TRACT=10704 [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.QUANTUM' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.QUANTUM='019e18fd-8afe-7626-9382-5c6edb88016b' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.N_INPUTS' types <class 'int'> and <class 'int'>, choosing LSST.BUTLER.N_INPUTS=13 [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.ID='019e18fd-8a60-71e3-87bf-8b6e36b2716f' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.RUN' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.RUN='u/xiangchl/dp1/a360_anacal/20260511T214156Z' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.0.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.0.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.1.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.1.ID='019e18fd-8a61-7117-9a1a-036e65925486' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.1.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.1.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.2.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.2.ID='019e18fd-8a61-7043-a57b-3103640573fd' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.2.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.2.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.3.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.3.ID='019e18fd-8a62-79c1-87ba-97af988bd99a' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.3.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.3.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.4.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.4.ID='019e18fd-8a5f-7738-a54c-68e0f2411375' [astropy.utils.metadata.merge]
# Total merged objects: 73322
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.4.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.4.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.5.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.5.ID='019e18fd-8a60-7f2c-b5fb-f25a8191fc8d' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.5.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.5.DATASETTYPE='deep_coadd_cell_anacal_fzb_point' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.6.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.6.ID='64c16b0a-0a1a-4f78-81e5-f49a9328c388' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.6.RUN' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.6.RUN='skymaps' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.6.DATASETTYPE' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.6.DATASETTYPE='skyMap' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.7.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.7.ID='019e18fd-8a5a-71f4-922c-7b177cb4e273' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.8.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.8.ID='019e18fd-8a5b-7ae4-8aae-400df781ec66' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.9.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.9.ID='019e18fd-8a5c-76a9-bd1a-ca95fad47dc6' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.10.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.10.ID='019e18fd-8a5d-747b-9100-81e8719a7450' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.11.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.11.ID='019e18fd-8a5e-7997-9c26-d4d5d1575da9' [astropy.utils.metadata.merge]
# WARNING: MergeConflictWarning: Cannot merge meta key 'LSST.BUTLER.INPUT.12.ID' types <class 'str'> and <class 'str'>, choosing LSST.BUTLER.INPUT.12.ID='019e18fd-8a5a-7bd4-aabd-3e83afda4464' [astropy.utils.metadata.merge]

# %% [markdown]
# ## 3. Per-band magnitudes

# %%
mag_zero = 31.4
for band in 'griz':
    flux = np.asarray(anacal_table[f'{band}_flux_fpfs1'])
    mag = np.full(len(anacal_table), 40.0)
    pos = flux > 0
    mag[pos] = mag_zero - 2.5 * np.log10(flux[pos])
    anacal_table[f'{band}_mag'] = mag

# %% [markdown]
# ## 4. Selection (with shear-perturbed observables)
#
# Cuts (matching the old notebook + new ``zbest`` cut):
#
# - ``mask_value < 40``
# - ``wsel > 1e-5``
# - per-band magnitude limits ``g/r/z < 25.5``, ``i < 24.0``
# - size-like cut ``(m00 + m20) / m00 > 0.1`` — uses the band-combined
#   ``fpfs1_m00`` / ``fpfs1_m20`` since per-band ``i_fpfs1_m00`` /
#   ``i_fpfs1_m20`` are not surfaced in the merged catalog
# - red-sequence colour count < 3 (``g-i``, ``r-i``, ``g-r``, $r$-mag)
# - photo-z ``Z_MIN < zbest < Z_MAX``
#
# When ``dg_eff != 0`` the per-band fluxes, ``m00``, ``m20`` and the
# photo-z column are all replaced by their first-order Taylor expansions
# in the chosen shear component, mirroring ``selection.get_cut`` in
# ``HSC_S23B_Shapes``.

# %%
DG = 0.01
Z_MIN, Z_MAX = 0.2, 10.0
MAG_CUTS = {'g': 25.5, 'r': 25.5, 'i': 23.5, 'z': 25.5}
MAG_LIM_REDSEQ = 24.0


def _flux_to_mag(flux):
    mag = np.full(len(flux), 40.0)
    pos = flux > 0
    mag[pos] = mag_zero - 2.5 * np.log10(flux[pos])
    return mag


def _band_mag(t, band, dg_eff, comp):
    flux = np.asarray(t[f'{band}_flux_fpfs1'])
    if dg_eff != 0.0:
        flux = flux + dg_eff * np.asarray(t[f'{band}_dflux_fpfs1_dg{comp}'])
    return _flux_to_mag(flux)


def _redseq_count(g_mag, r_mag, i_mag):
    color_gi = g_mag - i_mag
    color_ri = r_mag - i_mag
    color_gr = g_mag - r_mag
    gi_line = (r_mag - 18) * (-0.20 / 5) + 2.15
    ri_line = (r_mag - 18) * (-0.10 / 5) + 0.85
    gr_line = (r_mag - 18) * (-0.12 / 5) + 1.35
    gi_lims, ri_lims, gr_lims = (0.20, -0.20), (0.12, -0.15), (0.15, -0.16)
    in_redseq = lambda c, line, lims: (
        (c < line + lims[0]) & (c > line + lims[1]) & (r_mag < MAG_LIM_REDSEQ)
    )
    return (
        in_redseq(color_gi, gi_line, gi_lims).astype(int)
        + in_redseq(color_ri, ri_line, ri_lims).astype(int)
        + in_redseq(color_gr, gr_line, gr_lims).astype(int)
    )


def get_cut(t, *, comp=1, dg_eff=0.0, zkey='zbest'):
    """Boolean mask for the standard selection.

    The merged catalog is already filtered by ``wsel > 1e-5`` in
    ``MergePipe._finalize_columns``; ``dg_eff != 0`` perturbs every
    other shear-dependent observable by its first-order response so the
    resulting cut feeds the selection-response finite difference.
    """
    mags = {b: _band_mag(t, b, dg_eff, comp) for b in 'griz'}

    mask = np.asarray(t['mask_value']) < 40
    for b, lim in MAG_CUTS.items():
        mask &= mags[b] < lim

    m00 = np.asarray(t['fpfs1_m00'])
    m20 = np.asarray(t['fpfs1_m20'])
    if dg_eff != 0.0:
        m00 = m00 + dg_eff * np.asarray(t[f'fpfs1_dm00_dg{comp}'])
        m20 = m20 + dg_eff * np.asarray(t[f'fpfs1_dm20_dg{comp}'])
    mask &= (m00 + m20) / m00 > 0.1

    counts = _redseq_count(mags['g'], mags['r'], mags['i'])
    mask &= counts < 3

    if dg_eff == 0.0:
        zcol = np.asarray(t[f'{zkey}_0'])
    else:
        suffix = 'p' if dg_eff > 0 else 'm'
        zcol = np.asarray(t[f'{zkey}_{comp}{suffix}'])
    mask &= (zcol > Z_MIN) & (zcol < Z_MAX)
    return mask


fid_cut = get_cut(anacal_table, dg_eff=0.0)
cut_p1 = get_cut(anacal_table, comp=1, dg_eff=+DG)
cut_m1 = get_cut(anacal_table, comp=1, dg_eff=-DG)
cut_p2 = get_cut(anacal_table, comp=2, dg_eff=+DG)
cut_m2 = get_cut(anacal_table, comp=2, dg_eff=-DG)
print(f'Fiducial selected: {int(fid_cut.sum())}/{len(anacal_table)}')
for tag, c in [('1p', cut_p1), ('1m', cut_m1), ('2p', cut_p2), ('2m', cut_m2)]:
    print(f'  cut_{tag}: {int(c.sum())}')
# Out:
# Fiducial selected: 16847/73322
#   cut_1p: 16851
#   cut_1m: 16834
#   cut_2p: 16839
#   cut_2m: 16842

# %%
# --- response components (computed *before* TreeCorr so the calibrated
# ellipticities can be fed directly to it) ---
nc = int(fid_cut.sum())
sub = anacal_table[fid_cut]
wsel = np.asarray(sub['wsel'])
e1 = np.asarray(sub['fpfs1_e1'])
e2 = np.asarray(sub['fpfs1_e2'])
de1_dg1 = np.asarray(sub['fpfs1_de1_dg1'])
de2_dg2 = np.asarray(sub['fpfs1_de2_dg2'])
dwsel_dg1 = np.asarray(sub['dwsel_dg1'])
dwsel_dg2 = np.asarray(sub['dwsel_dg2'])

# Shape (pure-shear) response: <w * de_i/dg_i> averaged over i = 1, 2
R_shape = 0.5 * (np.mean(wsel * de1_dg1) + np.mean(wsel * de2_dg2))
# Weight-bias response: <dw/dg_i * e_i> averaged over i = 1, 2
R_weight = 0.5 * (np.mean(dwsel_dg1 * e1) + np.mean(dwsel_dg2 * e2))


def _sum_we(t, cut, comp):
    s = t[cut]
    e_col = 'fpfs1_e1' if comp == 1 else 'fpfs1_e2'
    return float(np.sum(np.asarray(s['wsel']) * np.asarray(s[e_col])))


R_sel_1 = (_sum_we(anacal_table, cut_p1, 1) - _sum_we(anacal_table, cut_m1, 1)) / (2.0 * DG) / nc
R_sel_2 = (_sum_we(anacal_table, cut_p2, 2) - _sum_we(anacal_table, cut_m2, 2)) / (2.0 * DG) / nc
R_sel = 0.5 * (R_sel_1 + R_sel_2)

R_total = R_shape + R_weight + R_sel
print(f'N selected = {nc}')
print(f'  R_shape  = {R_shape:+.4f}')
print(f'  R_weight = {R_weight:+.4f}')
print(f'  R_sel    = {R_sel:+.4f}')
print(f'  R_total  = {R_total:+.4f}')
# Out:
# N selected = 16847
#   R_shape  = +0.4476
#   R_weight = -0.0225
#   R_sel    = -0.0101
#   R_total  = +0.4151

# %%
# --- TreeCorr: pre-calibrate the ellipticities by feeding
#     g1 = e1 * wsel / R_total
#     g2 = e2 * wsel / R_total
# (no sign flip on e2 -- merge.py keeps the WCS-corrected ellipticities
# in the GalSim u=W convention, which is what TreeCorr expects for the
# tangential / cross decomposition around the cluster centre)
# and pass w=None so TreeCorr does not re-weight. The resulting
# xi / xi_im are already the response- and weight-corrected tangential
# and cross shears.
bins_mpc = np.logspace(np.log10(0.5), np.log10(6.0), 7)
nbins = len(bins_mpc) - 1
mpc_to_arcmin = (1.0 / Da_lens) * (180.0 / np.pi) * 60.0
min_sep_arcmin = bins_mpc[0] * mpc_to_arcmin
max_sep_arcmin = bins_mpc[-1] * mpc_to_arcmin
print(f'min/max sep: {min_sep_arcmin:.2f} / {max_sep_arcmin:.2f} arcmin')
print(f'Mpc bin edges: {bins_mpc.round(3)}')

lens_cat = treecorr.Catalog(
    ra=[ra_bcg], dec=[dec_bcg], ra_units='deg', dec_units='deg',
)


def make_source_cat(t, cut, R_final):
    sub = t[cut]
    wsel_sub = np.asarray(sub['wsel'])
    g1 = np.asarray(sub['fpfs1_e1']) * wsel_sub / R_final
    g2 = np.asarray(sub['fpfs1_e2']) * wsel_sub / R_final
    return treecorr.Catalog(
        ra=np.asarray(sub['ra']),
        dec=np.asarray(sub['dec']),
        g1=g1, g2=g2, w=None,
        ra_units='deg', dec_units='deg',
    )


src_cat = make_source_cat(anacal_table, fid_cut, R_total)
ng = treecorr.NGCorrelation(
    min_sep=min_sep_arcmin, max_sep=max_sep_arcmin,
    nbins=nbins, sep_units='arcmin', bin_type='Log',
)
ng.process(lens_cat, src_cat)
mean_r_arcmin = ng.meanr
mean_r_mpc = mean_r_arcmin / mpc_to_arcmin
print('mean_r (Mpc):', np.round(mean_r_mpc, 3))
# Out:
# min/max sep: 2.35 / 28.18 arcmin
# Mpc bin edges: [0.5   0.757 1.145 1.732 2.621 3.965 6.   ]
# mean_r (Mpc): [0.63  0.96  1.456 2.184 3.313 5.12 ]

# %% [markdown]
# ## 7. Tangential / cross shear profile

# %%
# xi / xi_im are already calibrated (no /R_total here -- the input
# ellipticities were pre-divided by R_total).
gT = ng.xi
gX = ng.xi_im
err = np.sqrt(ng.varxi)

fig, ax = plt.subplots(figsize=(7, 5))
ax.errorbar(mean_r_mpc, gT, yerr=err, fmt='o', label='tangential', color='C0')
ax.errorbar(mean_r_mpc * 1.05, gX, yerr=err, fmt='s', label='cross', color='C3', alpha=0.8)
ax.axhline(0, ls='--', color='k', alpha=0.5)
ax.set_xscale('log')
ax.set_xlabel('$R$ [Mpc]')
ax.set_ylabel('reduced shear')
ax.set_xlim(0.4, 7.0)
ax.legend()
plt.tight_layout()
plt.show()
